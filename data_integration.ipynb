# %% [markdown]
# ## Data integration

# %%
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd
import pandas as pd
from gnss_to_neu import convert_gnss_to_neu

# %%
data_gnss = pd.read_csv('gnss\gnss_data.csv')
data_insar_1 = pd.read_csv('insar\sentinel1_asc_t088_limburg.csv')
data_insar_2 = pd.read_csv('insar\sentinel1_dsc_t037_limburg.csv')
data_levelling = pd.read_csv('levelling\Levelling_NAP_ZL_20220616_redef.csv')

# %%
data_insar_1u = convert_gnss_to_neu(data_insar_1)
data_insar_2u = convert_gnss_to_neu(data_insar_2)

# %%
data_insar_1u.head()
# Out:
#    Unnamed: 0              pnt_id  pnt_flags    pnt_lat   pnt_lon  pnt_line  \
# 0    45198734  L00021513P00024254        101  51.069912  5.995160     21513
# 1    45198735  L00021513P00024256        101  51.069924  5.995082     21513
# 2    45198736  L00021513P00024258        101  51.069936  5.994990     21513
# 3    45198737  L00021513P00024266        101  51.069983  5.994527     21513
# 4    45198740  L00021513P00024270        101  51.069988  5.994491     21513
#
#    pnt_pixel  pnt_height  pnt_demheight  pnt_demheight_highres  ...  \
# 0      24254   100.53586       97.83295               97.83295  ...
# 1      24256    98.46797       97.63007               97.63007  ...
# 2      24258    98.23861       97.41656               97.41656  ...
# 3      24266    96.72467       94.12607               94.12607  ...
# 4      24270    90.49152       94.05100               94.05100  ...
#
#    u_d_20220628  u_d_20220722  u_d_20220803  u_d_20220815  u_d_20220827  \
# 0      0.018341     -0.005569      0.001169     -0.000679     -0.003910
# 1     -0.016732     -0.002967     -0.004488      0.001081     -0.000842
# 2     -0.013501     -0.007442     -0.005934     -0.004903     -0.004060
# 3     -0.010761     -0.011779     -0.006135     -0.004991     -0.006889
# 4     -0.009227     -0.010598     -0.006386     -0.006877     -0.006525
#
#    u_d_20220908  u_d_20220920  u_d_20221002  u_d_20221014  u_d_20221026
# 0      0.002112      0.015538      0.018354      0.007304      0.006763
# 1      0.000566     -0.008988      0.000390     -0.003608     -0.002326
# 2     -0.003444     -0.007417     -0.001546     -0.006738     -0.004802
# 3     -0.010547     -0.008209     -0.008775     -0.014193     -0.010811
# 4     -0.007040     -0.008071     -0.006776     -0.012571     -0.011465
#
# [5 rows x 172 columns]

# %%
data_insar_2u.head()
# Out:
#    Unnamed: 0              pnt_id  pnt_flags    pnt_lat   pnt_lon  pnt_line  \
# 0    45198734  L00021513P00024254        101  51.069912  5.995160     21513
# 1    45198735  L00021513P00024256        101  51.069924  5.995082     21513
# 2    45198736  L00021513P00024258        101  51.069936  5.994990     21513
# 3    45198737  L00021513P00024266        101  51.069983  5.994527     21513
# 4    45198740  L00021513P00024270        101  51.069988  5.994491     21513
#
#    pnt_pixel  pnt_height  pnt_demheight  pnt_demheight_highres  ...  \
# 0      24254   100.53586       97.83295               97.83295  ...
# 1      24256    98.46797       97.63007               97.63007  ...
# 2      24258    98.23861       97.41656               97.41656  ...
# 3      24266    96.72467       94.12607               94.12607  ...
# 4      24270    90.49152       94.05100               94.05100  ...
#
#    u_d_20220628  u_d_20220722  u_d_20220803  u_d_20220815  u_d_20220827  \
# 0      0.018341     -0.005569      0.001169     -0.000679     -0.003910
# 1     -0.016732     -0.002967     -0.004488      0.001081     -0.000842
# 2     -0.013501     -0.007442     -0.005934     -0.004903     -0.004060
# 3     -0.010761     -0.011779     -0.006135     -0.004991     -0.006889
# 4     -0.009227     -0.010598     -0.006386     -0.006877     -0.006525
#
#    u_d_20220908  u_d_20220920  u_d_20221002  u_d_20221014  u_d_20221026
# 0      0.002112      0.015538      0.018354      0.007304      0.006763
# 1      0.000566     -0.008988      0.000390     -0.003608     -0.002326
# 2     -0.003444     -0.007417     -0.001546     -0.006738     -0.004802
# 3     -0.010547     -0.008209     -0.008775     -0.014193     -0.010811
# 4     -0.007040     -0.008071     -0.006776     -0.012571     -0.011465
#
# [5 rows x 172 columns]
